# %% [markdown]
# <a href="https://colab.research.google.com/github/GEO-001/Brain-Explorer/blob/master/Copy_of_Gediformat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install laspy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 2.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
# Upload the .h5 file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45b4cbed-d7c1-4b1d-8975-e48354e71703" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45b4cbed-d7c1-4b1d-8975-e48354e71703">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
# List all files in the /content directory
files_in_content = os.listdir("/content")
print(files_in_content)
# Out:
# ['.config', 'GEDI04_A_2023075201011_O24115_04_T08796_02_003_01_V002.h5', 'sample_data']

# %%
import h5py
import laspy
import numpy as np

# %%
import os
import h5py
import pandas as pd
import numpy as np

# %%
import os
file_name = "GEDI04_A_2023075201011_O24115_04_T08796_02_003_01_V002.h5"
file_path = os.path.join("/content", file_name)

# %%
file_path = "/content/GEDI04_A_2023075201011_O24115_04_T08796_02_003_01_V002.h5"
f = h5py.File(file_path, 'r')
print(list(f.keys()))
# Out:
# ['ANCILLARY', 'BEAM0000', 'BEAM0001', 'BEAM0010', 'BEAM0011', 'BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011', 'METADATA']

# %%
h5_file = h5py.File ("/content/GEDI04_A_2023075201011_O24115_04_T08796_02_003_01_V002.h5")

# %%
def get_h5_structure(f, level=0):
    """    prints structure of hdf5 file    """
    for key in f.keys():
        if isinstance(f[key], h5py._hl.dataset.Dataset):
            print(f"{'  '*level} DATASET: {f[key].name}")
        elif isinstance(f[key], h5py._hl.group.Group):
            print(f"{'  '*level} GROUP: {f[key].name}")
            get_h5_structure(f[key], level+1)

# %%
f = h5py.File(file_path, 'r')
get_h5_structure(f)
# Out:
#  GROUP: /ANCILLARY
#    DATASET: /ANCILLARY/model_data
#    DATASET: /ANCILLARY/pft_lut
#    DATASET: /ANCILLARY/region_lut
#  GROUP: /BEAM0000
#    DATASET: /BEAM0000/agbd
#    DATASET: /BEAM0000/agbd_pi_lower
#    DATASET: /BEAM0000/agbd_pi_upper
#    GROUP: /BEAM0000/agbd_prediction
#      DATASET: /BEAM0000/agbd_prediction/agbd_a1
#      DATASET: /BEAM0000/agbd_prediction/agbd_a10
#      DATASET: /BEAM0000/agbd_prediction/agbd_a2
#      DATASET: /BEAM0000/agbd_prediction/agbd_a3
#      DATASET: /BEAM0000/agbd_prediction/agbd_a4
#      DATASET: /BEAM0000/agbd_prediction/agbd_a5
#      DATASET: /BEAM0000/agbd_prediction/agbd_a6
#      DATASET: /BEAM0000/agbd_prediction/agbd_pi_lower_a1
#      DATASET: /BEAM0000/agbd_prediction/agbd_pi_lower_a10
#      DATASET: /BEAM0000/agbd_prediction/agbd_pi_lower_a2
#      DATASET: /BEAM0000/agbd_prediction/agbd_pi_lower_a3
#      DATASET: /BEAM0000/agbd_prediction/agbd_pi_lower_a4
#      DATASET: /BEAM0000/agbd_prediction/agbd_pi_lower_a5
# ...

# %%
group = "BEAM0000"

# %%
n = f[group]["agbd"].shape[0]
print(n)
# Out:
# 101645

# %%
import pandas as pd
df = pd.DataFrame()

# %%
import laspy

# %%
pip install --upgrade pip setuptools
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.0 MB/s eta 0:00:00
# ...
#   Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...

# %%
# !pip uninstall laspy
# Out:
# WARNING: Skipping laspy as it is not installed.

# %%
# !pip install "laspy<2.0.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 2.0 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install laspy==1.7.0

# %%
import laspy
import laspy.file
from laspy.file import File

# %%
las_file = File ("output.las", mode = "w")
# Out:
# ---------------------------------------------------------------------------
# LaspyException                            Traceback (most recent call last)
# <ipython-input-23-e68d6b24a577> in <cell line: 1>()
# ----> 1 las_file = File ("output.las", mode = "w")
#
# /usr/local/lib/python3.10/dist-packages/laspy/file.py in __init__(self, *args, **kwargs)
#       4 class File:
#       5     def __init__(self, *args, **kwargs) -> None:
# ----> 6         raise errors.LaspyException(
#       7             """You are using laspy 2.0, which has several improvements over 1.x
#       8             but with several breaking changes.
#
# LaspyException: You are using laspy 2.0, which has several improvements over 1.x
#             but with several breaking changes.
#             To stay on laspy 1.x: `pip install laspy<2.0.0`
#
#             In short:
#               - To read a file do: las = laspy.read('somefile.laz')
# ...

# %%
import numpy as np

# %%
elevation = h5_file ["BEAM0000/geolocation/elev_lowestmode_a1"]
latitude = h5_file ["BEAM0000/geolocation/lat_lowestmode_a10"]
longitude = h5_file ["BEAM0000/geolocation/lon_lowestmode_a1"]

# %%
h5_file.close ()

# %%
las_file.X = (longitude * 1e7).astype (np.int32)
las_file.Y = (latitude * 1e7).astype (np.int32)
las_file.Z = (elevation * 100).astype (np.int32)

# %%
las_file.x = np.array(x_coordinates)
las_file.y = np.array(y_coordinates)
las_file.z = np.array(z_coordinates)
las_file.intensity = np.array(intensity_values)
las_file.time_created = np.datetime64('2023-01-01T00:00:00')
